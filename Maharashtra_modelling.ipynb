# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = 'DATA/Maharashtra.csv'
df_raw = pd.read_csv(PATH)

# %%
df_raw.head()
# Out:
#     State_Name District_Name  Crop_Year       Season       Crop      Area  \
# 0  Maharashtra    AHMEDNAGAR       1997  Autumn           Maize       1.0
# 1  Maharashtra    AHMEDNAGAR       1997  Kharif       Arhar/Tur   17600.0
# 2  Maharashtra    AHMEDNAGAR       1997  Kharif           Bajra  274100.0
# 3  Maharashtra    AHMEDNAGAR       1997  Kharif            Gram   40800.0
# 4  Maharashtra    AHMEDNAGAR       1997  Kharif           Jowar     900.0
#
#    Production
# 0      1113.0
# 1      6300.0
# 2    152800.0
# 3     18600.0
# 4      1100.0

# %%
df_raw.drop(['State_Name'], axis=1, inplace=True)

# %%
df_raw.head()
# Out:
#   District_Name  Crop_Year       Season       Crop      Area  Production
# 0    AHMEDNAGAR       1997  Autumn           Maize       1.0      1113.0
# 1    AHMEDNAGAR       1997  Kharif       Arhar/Tur   17600.0      6300.0
# 2    AHMEDNAGAR       1997  Kharif           Bajra  274100.0    152800.0
# 3    AHMEDNAGAR       1997  Kharif            Gram   40800.0     18600.0
# 4    AHMEDNAGAR       1997  Kharif           Jowar     900.0      1100.0

# %%
print("Unique crops: ",df_raw['Crop'].unique())
print("\nNumber of unique crops: ", df_raw['Crop'].nunique())
# Out:
# Unique crops:  ['Maize' 'Arhar/Tur' 'Bajra' 'Gram' 'Jowar' 'Moong(Green Gram)'
#  'Pulses total' 'Ragi' 'Rice' 'Sugarcane' 'Total foodgrain' 'Urad'
#  'Other  Rabi pulses' 'Wheat' 'Cotton(lint)' 'Castor seed' 'Groundnut'
#  'Niger seed' 'Other Cereals & Millets' 'Other Kharif pulses' 'Sesamum'
#  'Soyabean' 'Sunflower' 'Linseed' 'Rapeseed &Mustard' 'Safflower'
#  'Small millets' 'other oilseeds' 'Banana' 'Grapes' 'Mango' 'Onion'
#  'Tomato' 'Tobacco']
#
# Number of unique crops:  34

# %% [markdown]
# ### Getting frequency of crops

# %%
df_raw['Crop'].value_counts()
# Out:
# Maize                      1056
# Sunflower                   960
# Jowar                       875
# Groundnut                   869
# Sesamum                     673
# Rice                        654
# Moong(Green Gram)           573
# Arhar/Tur                   570
# Urad                        550
# Gram                        548
# Wheat                       518
# Soyabean                    477
# Cotton(lint)                465
# Sugarcane                   456
# Bajra                       386
# Rapeseed &Mustard           367
# Other Kharif pulses         342
# Safflower                   339
# Niger seed                  323
# Other  Rabi pulses          306
# Castor seed                 296
# Linseed                     281
# Small millets               210
# Ragi                        206
# Other Cereals & Millets      86
# other oilseeds               43
# Mango                        31
# Tomato                       30
# Total foodgrain              29
# ...

# %%
df_raw['District_Name'].value_counts()
# Out:
# AHMEDNAGAR    495
# PUNE          495
# SATARA        478
# PARBHANI      467
# LATUR         466
# BEED          464
# OSMANABAD     461
# NANDED        461
# NASHIK        459
# SOLAPUR       458
# SANGLI        452
# JALNA         435
# AURANGABAD    432
# DHULE         418
# KOLHAPUR      409
# BULDHANA      403
# JALGAON       402
# AMRAVATI      400
# NAGPUR        388
# HINGOLI       377
# NANDURBAR     377
# YAVATMAL      357
# AKOLA         355
# WARDHA        328
# CHANDRAPUR    325
# WASHIM        307
# GADCHIROLI    306
# BHANDARA      288
# THANE         268
# RAIGAD        236
# GONDIA        229
# RATNAGIRI     213
# SINDHUDURG    207
# PALGHAR        11
# MUMBAI          1
# Name: District_Name, dtype: int64

# %%
df_raw['Season'].value_counts()
# Out:
# Kharif         7275
# Rabi           3824
# Summer         1011
# Whole Year      511
# Autumn            7
# Name: Season, dtype: int64

# %%
df_raw[df_raw['District_Name'] == 'JALGAON']
# Out:
#      District_Name  Crop_Year       Season                Crop      Area  \
# 4492       JALGAON       1997  Autumn                    Maize       3.0
# 4493       JALGAON       1997  Kharif                Arhar/Tur   24100.0
# 4494       JALGAON       1997  Kharif                    Bajra   78000.0
# 4495       JALGAON       1997  Kharif                     Gram   50300.0
# 4496       JALGAON       1997  Kharif                    Jowar  159700.0
# ...            ...        ...          ...                 ...       ...
# 4889       JALGAON       2014  Rabi         Other  Rabi pulses     200.0
# 4890       JALGAON       2014  Rabi                      Wheat   49600.0
# 4891       JALGAON       2014  Summer                Groundnut    2400.0
# 4892       JALGAON       2014  Summer                    Maize    9400.0
# 4893       JALGAON       2014  Whole Year            Sugarcane    7900.0
#
#       Production
# 4492      3980.0
# 4493      7300.0
# 4494     90400.0
# 4495     32300.0
# ...

# %%
df_raw[df_raw['District_Name'] == 'PUNE']
# Out:
#      District_Name  Crop_Year       Season       Crop      Area  Production
# 8829          PUNE       1997  Autumn           Maize       4.0      4570.0
# 8830          PUNE       1997  Kharif       Arhar/Tur    3900.0      2900.0
# 8831          PUNE       1997  Kharif           Bajra  135700.0    112000.0
# 8832          PUNE       1997  Kharif            Gram   43400.0     26100.0
# 8833          PUNE       1997  Kharif           Jowar    4200.0      5200.0
# ...            ...        ...          ...        ...       ...         ...
# 9319          PUNE       2014  Rabi         Sunflower     300.0       200.0
# 9320          PUNE       2014  Rabi             Wheat   71800.0    108300.0
# 9321          PUNE       2014  Summer       Groundnut    8400.0     19100.0
# 9322          PUNE       2014  Summer           Maize    1100.0      1600.0
# 9323          PUNE       2014  Whole Year   Sugarcane  127800.0  13833900.0
#
# [495 rows x 6 columns]

# %% [markdown]
# ## To-Do

# %% [markdown]
# 1. Seperate datasets for each city
# 2. Remove PALGHAR, MUMBAI district
# 3. Remove Autumn season
# 4. Remove these rows from crop column
#     - Other Cereals & Millets
#     - other oilseeds
#     - Mango
#     - Tomato
#     - Total foodgrain
#     - Pulses total
#     - Banana
#     - Onion
#     - Grapes
#     - Tobacco
# 5. Make a function which takes in the dataset and do all the above steps mentioned
